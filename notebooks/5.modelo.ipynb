# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
import sys
from pathlib import Path

# Agregar la carpeta raíz al path para poder importar
carpeta_raiz = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(carpeta_raiz))

# Importar las funciones
from funciones_save_load import guardar_parquet, cargar_parquet

x_train = cargar_parquet("x_train.parquet")
x_test  = cargar_parquet("x_test.parquet")

y_train = cargar_parquet("y_train.parquet")["puntaje_global"]
y_test  = cargar_parquet("y_test.parquet")["puntaje_global"]

# %%
# Out:
#        tipo_documento nacionalidad     genero pertenece_etnia estrato_casa  \
# 0                  TI     Colombia   Femenino              No    Estrato 1
# 1                  TI     Colombia   Femenino              No    Estrato 2
# 2                  TI     Colombia  Masculino              No    Estrato 2
# 3                  TI     Colombia  Masculino              No    Estrato 2
# 4                  TI     Colombia   Femenino              No    Estrato 2
# ...               ...          ...        ...             ...          ...
# 403827             TI     Colombia  Masculino              No    Estrato 3
# 403828             TI     Colombia  Masculino              No    Estrato 2
# 403829             TI     Colombia   Femenino              No    Estrato 1
# 403830             TI     Colombia  Masculino              No    Estrato 1
# 403831             TI     Colombia   Femenino              No    Estrato 1
#
#        num_personas_casa cuartos_casa               educacion_padre  \
# 0                  7 a 8          Dos                           NaN
# 1                  3 a 4          Dos  Tecnico/Tecnologo incompleta
# 2                  5 a 6          Dos                   Profesional
# 3                  3 a 4          Dos                           NaN
# 4                  3 a 4         Tres                           NaN
# ...                  ...          ...                           ...
# 403827             5 a 6         Tres                           NaN
# 403828             3 a 4          Dos           Primaria incompleta
# 403829             5 a 6          Dos                           NaN
# 403830             7 a 8        Cinco                           NaN
# 403831             1 a 2         Tres             Tecnico/Tecnologo
#
#             educacion_madre           actividad_padre  \
# 0         Tecnico/Tecnologo  Trabajador independiente
# 1                       NaN   Trabajadores operativos
# 2               Profesional             Profesionales
# 3         Tecnico/Tecnologo   Trabajadores operativos
# 4                       NaN   Trabajadores operativos
# ...                     ...                       ...
# 403827                  NaN   Trabajadores operativos
# 403828  Primaria incompleta           Sector primario
# 403829                  NaN           Microempresario
# 403830                  NaN                Directivos
# 403831                  NaN  Trabajador independiente
#
#                  actividad_madre internet  tv computador lavadora microndas  \
# 0       Sin actividad remunerada       No  No         No       No        No
# 1        Trabajadores operativos       Si  Si         Si       Si        No
# 2                  Profesionales       Si  Si         Si       Si        Si
# 3                Microempresario       Si  No         Si       Si        No
# 4        Trabajadores operativos       Si  Si         Si       Si        No
# ...                          ...      ...  ..        ...      ...       ...
# 403827  Sin actividad remunerada       Si  Si         Si       Si        No
# 403828           Sector primario       No  No         No       No        Si
# 403829           Microempresario       No  No         No       Si        Si
# 403830   Trabajadores operativos       No  No         Si       No        No
# 403831           Microempresario       Si  No         Si       Si        No
#
#        carro moto consola  num_libros_casa          come_derivados_leche  \
# 0         No   No      No   11 a 25 libros        3 a 5 veces por semana
# 1         Si   No      No   11 a 25 libros  Nunca o rara vez comemos eso
# 2         Si   Si      Si  26 a 100 libros   Todos o casi todos los días
# 3         No   No      No   11 a 25 libros        1 o 2 veces por semana
# 4         No   No      No   11 a 25 libros        3 a 5 veces por semana
# ...      ...  ...     ...              ...                           ...
# 403827    No   No      No   11 a 25 libros   Todos o casi todos los días
# 403828    No   Si      No    0 a 10 libros        3 a 5 veces por semana
# 403829    No   Si      No    0 a 10 libros        1 o 2 veces por semana
# 403830    No   No      No  26 a 100 libros        3 a 5 veces por semana
# 403831    No   No      No    0 a 10 libros  Nunca o rara vez comemos eso
#
#             come_carne_pescado_huevo come_cereal_frutas_legumbres  \
# 0        Todos o casi todos los días  Todos o casi todos los días
# 1             1 o 2 veces por semana       1 o 2 veces por semana
# 2        Todos o casi todos los días       1 o 2 veces por semana
# 3             1 o 2 veces por semana       1 o 2 veces por semana
# 4        Todos o casi todos los días       1 o 2 veces por semana
# ...                              ...                          ...
# 403827        3 a 5 veces por semana       1 o 2 veces por semana
# 403828   Todos o casi todos los días       1 o 2 veces por semana
# 403829        1 o 2 veces por semana       1 o 2 veces por semana
# 403830  Nunca o rara vez comemos eso       1 o 2 veces por semana
# 403831        1 o 2 veces por semana  Todos o casi todos los días
#
#                         cuanto_lee      cuanto_navega_web  \
# 0                   Más de 2 horas     30 minutos o menos
# 1               30 minutos o menos         Más de 3 horas
# 2                Entre 1 y 2 horas      Entre 1 y 3 horas
# 3                Entre 1 y 2 horas      Entre 1 y 3 horas
# 4               30 minutos o menos      Entre 1 y 3 horas
# ...                            ...                    ...
# 403827  No leo por entretenimiento         Más de 3 horas
# 403828          30 minutos o menos     30 minutos o menos
# 403829          30 minutos o menos  Entre 30 y 60 minutos
# 403830       Entre 30 y 60 minutos  Entre 30 y 60 minutos
# 403831          30 minutos o menos         Más de 3 horas
#
#        horas_trabajo_semanal colegio_genero colegio_oficial colegio_bilingue  \
# 0                 No trabaja          Mixto         Oficial               No
# 1                 No trabaja          Mixto      No oficial               No
# 2                 No trabaja          Mixto      No oficial               No
# 3                 No trabaja          Mixto         Oficial               No
# 4                 No trabaja          Mixto         Oficial               No
# ...                      ...            ...             ...              ...
# 403827            No trabaja          Mixto      No oficial               No
# 403828       Tiempo completo          Mixto         Oficial               No
# 403829     Trabajo ocasional          Mixto         Oficial               No
# 403830     Trabajo ocasional          Mixto         Oficial               No
# 403831            No trabaja          Mixto         Oficial               No
#
#              tipo_colegio colegio_urbano_rural colegio_jornada  dpto_colegio  \
# 0               Académico               Urbano           Unica     Atlantico
# 1               Académico               Urbano        Completa        Bogotá
# 2               Académico               Urbano          Mañana         Sucre
# 3       Técnico/académico               Urbano        Completa     Antioquia
# 4               Académico               Urbano           Tarde        Bogotá
# ...                   ...                  ...             ...           ...
# 403827                NaN               Urbano          Mañana        Bogotá
# 403828  Técnico/académico                Rural        Sabatina  Cundinamarca
# 403829          Académico               Urbano           Unica         Cesar
# 403830          Académico               Urbano          Mañana       Bolivar
# 403831  Técnico/académico               Urbano          Mañana       Bolivar
#
#         edad               educacion_padres
# 0       17.0              Educación Técnica
# 1       16.0  Educación Superior Incompleta
# 2       17.0             Educación Superior
# 3       17.0              Educación Técnica
# 4       17.0                Sin Información
# ...      ...                            ...
# 403827  18.0                Sin Información
# 403828  19.0  Educación Primaria Incompleta
# 403829  16.0                Sin Información
# 403830  16.0                Sin Información
# 403831  16.0              Educación Técnica
#
# [403832 rows x 35 columns]
